# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import statistics

# %%
main_set = pd.read_csv("D:/Project/Sample data/Sam_8/train_numeric_sample.csv")

# %%
main_set.head(10)
# Out:
#    Unnamed: 0  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  \
# 0         428     0.115     0.063    -0.215    -0.179     0.031     -0.112
# 1         625       NaN       NaN       NaN       NaN       NaN        NaN
# 2        1046    -0.023    -0.004     0.003    -0.016     0.031      0.070
# 3        1228    -0.134    -0.078     0.003    -0.016     0.118     -0.021
# 4        1311     0.049     0.019    -0.179    -0.216    -0.100     -0.294
# 5        1660       NaN       NaN       NaN       NaN       NaN        NaN
# 6        1716       NaN       NaN       NaN       NaN       NaN        NaN
# 7        1744    -0.029     0.033     0.348     0.330     0.074      0.161
# 8        2110     0.003    -0.011    -0.015    -0.052     0.074      0.161
# 9        2543    -0.029    -0.041    -0.215    -0.179    -0.317     -0.021
#
#    L0_S0_F12  L0_S0_F14  L0_S0_F16  ...  L3_S50_F4245  L3_S50_F4247  \
# 0     -0.030     -0.112     -0.021  ...           NaN           NaN
# 1        NaN        NaN        NaN  ...           NaN           NaN
# 2      0.008      0.008      0.051  ...           NaN           NaN
# 3      0.022      0.088      0.240  ...           NaN           NaN
# 4     -0.022     -0.072     -0.021  ...           NaN           NaN
# 5        NaN        NaN        NaN  ...           NaN           NaN
# 6        NaN        NaN        NaN  ...           NaN           NaN
# 7      0.022      0.088      0.041  ...           NaN           NaN
# 8     -0.007      0.008     -0.067  ...           NaN           NaN
# 9     -0.007     -0.032     -0.179  ...           NaN           NaN
#
#    L3_S50_F4249  L3_S50_F4251  L3_S50_F4253  L3_S51_F4256  L3_S51_F4258  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN           NaN
#
#    L3_S51_F4260  L3_S51_F4262  Response
# 0           NaN           NaN         0
# 1           NaN           NaN         0
# 2           NaN           NaN         0
# 3           NaN           NaN         0
# 4           NaN           NaN         0
# 5           NaN           NaN         0
# 6           NaN           NaN         0
# 7           NaN           NaN         0
# 8           NaN           NaN         0
# 9           NaN           NaN         0
#
# [10 rows x 970 columns]

# %%
numeric_cols = pd.read_csv("D:/Project/Sample data/Sam_8/train_numeric_sample.csv", usecols=['L0_S0_F0'])

# %%
numeric_cols= numeric_cols.head(20)

# %%
numeric_cols
# Out:
#     L0_S0_F0
# 0      0.115
# 1        NaN
# 2     -0.023
# 3     -0.134
# 4      0.049
# 5        NaN
# 6        NaN
# 7     -0.029
# 8      0.003
# 9     -0.029
# 10       NaN
# 11       NaN
# 12     0.069
# 13     0.036
# 14    -0.029
# 15       NaN
# 16       NaN
# 17       NaN
# 18    -0.055
# 19       NaN

# %%
my_list = numeric_cols["L0_S0_F0"].values
my_list1 = list(numeric_cols.index.values)

# %%
import matplotlib.pyplot as plt

x= my_list1
y= my_list

plt.bar(x,y)

plt.title('Bar Graph of Column')

plt.xlabel('Index')

plt.ylabel('Value')

plt.show()

# %%
 statistics.stdev(my_list)
# Out:
# nan

# %%
shape, scale = 2., 2.  # mean=4, std=2*sqrt(2)
mu = shape*scale
sigma = scale*np.sqrt(shape)
s = np.random.gamma(shape, scale, 1000000)

# %%
len(s)
# Out:
# 1000000

# %%
# sample 10000 sample
rs = random.choices(s, k=10000)

# %%
rs
# Out:
# [5.351182165083679,
#  3.500958156674776,
#  3.7067642841032944,
#  0.6885910584827297,
#  1.0540621689264298,
#  1.0225889933961572,
#  6.17371878481247,
#  4.393768301129317,
#  6.749628640153382,
#  1.2406633452323348,
#  4.752225327369015,
#  2.0014821339324556,
#  2.8027038980519112,
#  7.27548927602182,
#  1.8750136639352908,
#  7.124650469909232,
#  2.1289868028341963,
#  1.8641303123287598,
#  1.1250052281955685,
#  6.030075070061395,
#  2.569109331973245,
#  0.986855975242452,
#  6.973014721489479,
#  4.186866808788726,
#  3.262470177010612,
#  5.620684990051656,
#  7.213148277008198,
#  1.7479768364725299,
#  9.323480291502413,
#  1.6607591635747363,
#  3.5480764559133533,
#  4.650190122462003,
#  2.860366163234131,
#  6.5014440921654195,
#  4.887532876774369,
#  2.1015082224516974,
#  1.9963183722426352,
#  6.892101423546215,
#  1.716543320353764,
#  9.086478884844473,
#  7.021921617164579,
#  1.4331408231198806,
#  3.5519927383861902,
#  1.8748934919775189,
#  10.040331996861612,
#  3.427978422248302,
#  11.082432284179632,
#  3.9805721144316015,
#  8.619642112169693,
#  4.026575419159847,
#  6.158218965581432,
#  1.5764557293300678,
#  3.9217669428282886,
#  0.8210367290453338,
#  3.235925828921635,
#  5.609366127514369,
#  0.35357292054798484,
#  4.958460080038998,
#  4.3330374881970855,
#  4.7541806493046606,
#  3.257621284973655,
#  4.17078202181974,
#  3.4976496908110355,
#  3.8202792595021657,
#  3.1186118276150183,
#  4.124415958598399,
#  2.7768165994867484,
#  5.359747721128003,
#  4.12405901157927,
#  3.310829404413979,
#  2.105579885764506,
#  0.3065739130702823,
#  2.246798508605471,
#  8.01332716037108,
#  6.368737236819517,
#  6.07023210062139,
#  5.109881880656313,
#  1.5123413747089456,
#  6.154806384452825,
#  3.1276782796074873,
#  0.7139682327774102,
#  3.622729442247352,
#  4.819274029222818,
#  2.8089851459018287,
#  2.1110604987897292,
#  6.362559801116345,
#  1.2384836066381895,
#  2.989560859303581,
#  1.3535058374784228,
#  3.110639508936691,
#  2.0761487029052867,
#  3.3766553124564136,
#  7.269669583510349,
#  4.442240707525297,
#  4.701708868169824,
#  11.736272554289913,
#  4.431295711368368,
#  1.5801180656318907,
#  4.104334488530712,
#  5.855088437563141,
#  3.4586504887589107,
#  6.3037728209883035,
#  3.0616236823479057,
#  6.891922722347578,
#  3.105369541225118,
#  3.08970681886981,
#  7.466500138718292,
#  1.771473333808266,
#  5.011201080562697,
#  3.4464717875236106,
#  6.035148969093741,
#  6.531210180027301,
#  1.1069801852290584,
#  0.6893564850300454,
#  0.6805862541174993,
#  2.2864055090688717,
#  2.2797750024335,
#  5.886571235261317,
#  3.354972029113453,
#  7.458713482912007,
#  5.473607939215987,
#  1.742583695826849,
#  4.7740073695506915,
#  2.0287157051557805,
#  2.174861441029938,
#  0.53527096276351,
#  2.0304919483825707,
#  3.2205838367446846,
#  4.275679318488492,
#  4.498377569743645,
#  1.2297082792996403,
#  8.4613419376026,
#  2.720995500982892,
#  6.568394850245946,
#  1.2433379132157683,
#  14.093604570364338,
#  5.427209328652274,
#  1.3935258840233233,
#  2.4741524040510465,
#  0.679071931222601,
#  3.387675909927804,
#  8.303699630379619,
#  5.251112562068379,
#  1.413047591667985,
#  0.4092857943336855,
#  3.1186004108006213,
#  6.1517044669367715,
#  3.0892066209906006,
#  5.4307355592415645,
#  3.5308584758346004,
#  4.904661623360595,
#  3.0160990366406835,
#  0.7268274808397416,
#  1.929633410975796,
#  2.6662902089566467,
#  3.339182258723584,
#  8.74786188032409,
#  4.739038671645095,
#  6.901212250362942,
#  1.295861655498998,
#  8.847427643353416,
#  0.27522267622961816,
#  5.5167725868285595,
#  2.2613039773794372,
#  1.04407093426666,
#  2.4672121313774986,
#  8.059112911542597,
#  0.5782914971747617,
#  1.3093201590718349,
#  4.468388908017688,
#  2.242276393118145,
#  2.2915889926438,
#  2.0296981045697056,
#  7.264287074703534,
#  5.12118006790618,
#  0.15361132869922883,
#  6.975528559599534,
#  2.0125929961326556,
#  5.595661780066756,
#  1.8739534425411506,
#  3.609806133049551,
#  3.2839687165647318,
#  4.593205587735826,
#  4.115762867992422,
#  1.7207016442258292,
#  8.736915338107918,
#  1.5494468103278456,
#  0.8015442369822485,
#  6.202318832059608,
#  2.430415963743485,
#  1.3709480238743965,
#  6.061588803408075,
#  6.315319511423377,
#  1.1507278351781665,
#  6.067293408698926,
#  5.663141966265628,
#  3.2702915385809668,
#  4.050274525460818,
#  5.528686479025764,
#  4.193031794524746,
#  4.566775678627929,
#  6.014482204434156,
#  4.573909755786395,
#  3.1523873915504224,
#  1.1216474952637625,
#  2.5870999497413556,
#  3.4339636587841222,
#  0.7929203125998029,
#  4.794438873593123,
#  1.2926286559787779,
#  14.289452885602534,
#  8.959644504905697,
#  0.48246552999372244,
#  7.402133691429146,
#  5.1090923502357075,
#  1.0428756348721335,
#  3.0785058680319444,
#  5.4375085876567315,
#  0.7527601542372755,
#  9.5122981251953,
#  4.405733516743458,
#  4.001328240673921,
#  14.234411363775251,
#  4.380368515488241,
#  1.2188258918858164,
#  5.120915546944257,
#  4.213113748673566,
#  1.09918819247094,
#  2.080585781999619,
#  1.0370068548107192,
#  3.194842485196987,
#  3.0016918662884216,
#  8.572510675470342,
#  4.5629190847971755,
#  0.28669379263745537,
#  1.1130955508883975,
#  4.009612742830978,
#  2.767290469677729,
#  2.8307578371626247,
#  1.392716872292537,
#  6.106682786888692,
#  5.339020802328221,
#  4.289922964432057,
#  1.0398582802405796,
#  1.703083070545807,
#  6.040631590425045,
#  5.386865658294936,
#  0.1002719911462444,
#  5.073998578698339,
#  2.963997424242121,
#  2.162529633213629,
#  5.051234136235227,
#  3.9286277193837704,
#  9.922331197272463,
#  8.109185189065162,
#  0.7049688991957974,
#  0.1971273792000739,
#  7.930692690612908,
#  3.7937290890426945,
#  3.5815241570869727,
#  3.2319655172676445,
#  0.9057944614990647,
#  2.1907955469074714,
#  0.4238274722775803,
#  6.524158982992071,
#  2.7436802526852007,
#  3.2450691652025587,
#  1.7570740423268238,
#  1.8043919955473664,
#  0.45452345857130394,
#  3.2822670090373607,
#  1.765610287810255,
#  2.833271895476718,
#  7.17354416054368,
#  3.7074543918915523,
#  5.734841864311767,
#  2.876599912938523,
#  5.2439297362938815,
#  3.169016007727435,
#  10.895251539308607,
#  1.1717558097199707,
#  6.178857738642119,
#  3.2753940083623374,
#  10.163427279789573,
#  0.8052800690846421,
#  3.8911413502041667,
#  1.8185246234940942,
#  2.2102583010453367,
#  8.054037962798947,
#  1.355952831035704,
#  4.799531660521954,
#  1.2300444927943324,
#  4.203578418721795,
#  3.61532649121408,
#  9.378533584674773,
#  11.20597599420831,
#  6.489369750174845,
#  1.9610700903483147,
#  4.085849664551644,
#  0.6981706668951747,
#  3.015233074578407,
#  1.6679070366791953,
#  9.424775422698724,
#  1.7701541068269537,
#  6.619314387430649,
#  7.7588781527515644,
#  4.3882270113649255,
#  1.3983011805644938,
#  2.7358083798357424,
#  5.867506446623271,
#  1.2475422832373302,
#  1.7745493322941328,
#  3.5536620986537777,
#  7.857530420840274,
#  2.7229145308174894,
#  9.662193078246426,
#  0.47280352263139364,
#  2.435304710149186,
#  2.206681394912999,
#  3.235879925938092,
#  3.493603022486996,
#  4.297226483725959,
#  4.930649886558397,
#  8.126844159542971,
#  5.6643583840834015,
#  5.622107590295217,
#  10.338209228410404,
#  4.1155827557009586,
#  1.5212395341063918,
#  4.540397173498399,
#  2.858311933283692,
#  8.073148565044178,
#  0.5493230723503377,
#  2.214993618906793,
#  6.686104477026209,
#  10.685924910188481,
#  2.2116975698191728,
#  7.274496930689235,
#  1.4377223687108014,
#  4.380267579618801,
#  1.9213101009048628,
#  2.6196294761876278,
#  4.950952300788736,
#  6.5076336181790975,
#  9.873028727875857,
#  8.823299152364815,
#  7.940524018221873,
#  2.404326469251591,
#  7.8779055173158685,
#  1.8731892691486156,
#  0.28212542682080627,
#  2.7417164177778552,
#  4.310332211963551,
#  11.782774494374886,
#  0.9027549492638223,
#  9.281866787175657,
#  2.4348698803514033,
#  0.7008786204787965,
#  1.869354290114704,
#  1.720489596371474,
#  6.012519112408756,
#  6.658882444376425,
#  2.044343601676232,
#  9.921694284217121,
#  1.0410339671301725,
#  7.117437335819683,
#  8.348890031749825,
#  12.981586566865413,
#  1.1490457631480178,
#  2.1014191058854537,
#  5.43304142654024,
#  2.171748573269544,
#  2.305758370300088,
#  2.5654214622656952,
#  1.9276728191258712,
#  7.046544910667535,
#  2.0553527067505013,
#  2.2348727197566944,
#  1.7601555092739973,
#  8.136083353456502,
#  1.3449921067488118,
#  7.021238281797896,
#  2.9476509508920077,
#  4.218303016141141,
#  5.693398853362673,
#  1.8918719515179205,
#  4.114150800609321,
#  1.63351057759309,
#  2.6451350346839964,
#  2.2745949125158518,
#  2.103692676610421,
#  3.329167281357865,
#  6.775478713398299,
#  0.9896223503074927,
#  5.476237925376963,
#  3.3453540731327003,
#  3.9119456210860246,
#  4.7359759914417365,
#  12.950601803871882,
#  0.5808337890613864,
#  5.542964070689348,
#  0.9400024379188698,
#  1.025884739690183,
#  2.8865370298686286,
#  2.0588912966418214,
#  3.115261844796611,
#  0.4652715156386826,
#  10.226394007057674,
#  4.929717616051188,
#  5.42053697571595,
#  0.4260153614758263,
#  3.753713146308307,
#  3.637668511085281,
#  4.127572681496205,
#  9.205819886772574,
#  2.754711651633079,
#  0.9633605763487367,
#  5.434352566036331,
#  8.247452067968144,
#  4.193366012411274,
#  8.74383381481202,
#  6.104098007300067,
#  3.2483172973818286,
#  7.592884128454537,
#  2.3840352059093703,
#  2.147227291455268,
#  3.494422505377018,
#  5.588918086853324,
#  3.8588607728940327,
#  6.931289215392269,
#  5.557350501147791,
#  5.657062302892582,
#  3.080521283062125,
#  9.876763393137516,
#  5.601042365108528,
#  0.9864401393046095,
#  2.5838785362348267,
#  10.60270333076237,
#  4.696791513022942,
#  3.705180008106986,
#  8.212602303220832,
#  3.9486577573460497,
#  3.170039171244393,
#  4.269580768454956,
#  6.300381941131684,
#  10.20706199806493,
#  7.747103538012043,
#  1.124310359429509,
#  6.591089647423382,
#  2.505783403539269,
#  5.312436040209646,
#  2.8555079401007144,
#  3.8048000040422933,
#  1.0949849578012592,
#  6.529367488676652,
#  1.8991972812604412,
#  6.630148027694236,
#  5.592586777634425,
#  4.672118737954202,
#  1.5930903441506468,
#  7.921774626004988,
#  4.578695890753624,
#  ...]

# %%
import matplotlib.pyplot as plt
rng = np.random.RandomState(10)  # deterministic random data
a = np.hstack(rs)
plt.figure(figsize=(20,10)) 
plt.hist(a, bins='auto')  # arguments are passed to np.histogram
plt.title("Histogram with 'auto' bins")
plt.show()

# %%
def Average(rs): 
    return sum(rs) / len(rs)

# %%
average = Average(rs)

# %%
average
# Out:
# 4.0192935453051435

# %%
# set k
ks = [0.1,0.5,1.0,1.5,2.0,2.5,3.0]
# prob list
probs = []
# for each k
for k in ks: 
    # start count
    c = 0
    # for each data sample
    for i in rs:
        # count if far from mean in k standard deviation
        if abs(i - mu) > k * sigma :
            c += 1
    # count divided by number of sample
    probs.append(c/10000)

# %%
# set figure size
plt.figure(figsize=(20,10))
# plot each probability
plt.plot(ks,probs, marker='o')
# show plot
plt.show()
# print each probability
print("Probability of a sample far from mean more than k standard deviation:")
for i, prob in enumerate(probs):
    print("k:" + str(ks[i]) + ", probability: " \
          + str(prob)[0:5] + \
          " | in theory, probability should less than: " \
          + str(1/ks[i]**2)[0:5])
# Out:
# Probability of a sample far from mean more than k standard deviation:
# k:0.1, probability: 0.928 | in theory, probability should less than: 99.99
# k:0.5, probability: 0.628 | in theory, probability should less than: 4.0
# k:1.0, probability: 0.267 | in theory, probability should less than: 1.0
# k:1.5, probability: 0.085 | in theory, probability should less than: 0.444
# k:2.0, probability: 0.047 | in theory, probability should less than: 0.25
# k:2.5, probability: 0.025 | in theory, probability should less than: 0.16
# k:3.0, probability: 0.014 | in theory, probability should less than: 0.111
