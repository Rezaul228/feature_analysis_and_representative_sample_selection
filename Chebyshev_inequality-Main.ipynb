# %%
import pandas as pd
import numpy as np
from numpy import*

# %%
train_date =pd.read_csv('D:/Project/Sample data/Sam_8/train_numeric_1000k.csv',index_col=0)
#matrix2 = matrix('3,2,4,2,4;5,2,6,1,4;3,4,1,3,2;7,2,1,4,1;4,5,4,5,4;2,3,4,5,7;6,5,2,3,5')

# %%
train_date
# Out:
#          L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  \
# Id
# 6             NaN       NaN       NaN       NaN       NaN        NaN
# 9          -0.036    -0.064     0.294     0.330     0.074      0.161
# 82         -0.016     0.041    -0.179    -0.197    -0.273     -0.430
# 91          0.036     0.101    -0.161    -0.179    -0.100      0.116
# 92          0.108     0.093    -0.052    -0.034     0.031      0.116
# 93         -0.029    -0.071    -0.015     0.003     0.031      0.116
# 123        -0.023    -0.034    -0.197    -0.161    -0.056      0.070
# 166           NaN       NaN       NaN       NaN       NaN        NaN
# 191           NaN       NaN       NaN       NaN       NaN        NaN
# 226        -0.003    -0.034    -0.215    -0.161     0.118      0.025
# 258           NaN       NaN       NaN       NaN       NaN        NaN
# 259           NaN       NaN       NaN       NaN       NaN        NaN
# ...

# %%
train_date = train_date.head(10000)
train_date
# Out:
#         L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  \
# Id
# 6            NaN       NaN       NaN       NaN       NaN        NaN
# 9         -0.036    -0.064     0.294     0.330     0.074      0.161
# 82        -0.016     0.041    -0.179    -0.197    -0.273     -0.430
# 91         0.036     0.101    -0.161    -0.179    -0.100      0.116
# 92         0.108     0.093    -0.052    -0.034     0.031      0.116
# 93        -0.029    -0.071    -0.015     0.003     0.031      0.116
# 123       -0.023    -0.034    -0.197    -0.161    -0.056      0.070
# 166          NaN       NaN       NaN       NaN       NaN        NaN
# 191          NaN       NaN       NaN       NaN       NaN        NaN
# 226       -0.003    -0.034    -0.215    -0.161     0.118      0.025
# 258          NaN       NaN       NaN       NaN       NaN        NaN
# 259          NaN       NaN       NaN       NaN       NaN        NaN
# 269          NaN       NaN       NaN       NaN       NaN        NaN
# ...

# %%
train_date = train_date.fillna(train_date.mean())

# %%
train_date.head()
# Out:
#     L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# Id
# 6  -0.002354 -0.002962 -0.000949 -0.001195  0.000837   0.004747   0.000382
# 9  -0.036000 -0.064000  0.294000  0.330000  0.074000   0.161000   0.022000
# 82 -0.016000  0.041000 -0.179000 -0.197000 -0.273000  -0.430000  -0.007000
# 91  0.036000  0.101000 -0.161000 -0.179000 -0.100000   0.116000  -0.015000
# 92  0.108000  0.093000 -0.052000 -0.034000  0.031000   0.116000  -0.022000
#
#     L0_S0_F14  L0_S0_F16  L0_S0_F18  ...  L3_S50_F4245  L3_S50_F4247  \
# Id                                   ...
# 6    0.002095   0.000978   0.001397  ...     -0.000004      0.000023
# 9    0.128000  -0.026000  -0.046000  ...     -0.000004      0.000023
# 82  -0.072000  -0.092000  -0.174000  ...     -0.000004      0.000023
# 91  -0.152000   0.316000  -0.056000  ...     -0.000004      0.000023
# 92  -0.072000  -0.067000   0.109000  ...     -0.000004      0.000023
#
# ...

# %%
# Minimum values in column 
#min_Values_column = train_date.min(axis=1)

# %%
#Is there any NAN in column Code?
train_date.isnull().values.any()
# Out:
# False

# %%
#Column with NAN return code 
Column_With_NAN=train_date.loc[:, train_date.isna().any()]

# %%
# Drop column which contains NAN  
train_date=train_date.dropna(axis='columns')

# %%
train_date.head()
# Out:
#     L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# Id
# 6  -0.002354 -0.002962 -0.000949 -0.001195  0.000837   0.004747   0.000382
# 9  -0.036000 -0.064000  0.294000  0.330000  0.074000   0.161000   0.022000
# 82 -0.016000  0.041000 -0.179000 -0.197000 -0.273000  -0.430000  -0.007000
# 91  0.036000  0.101000 -0.161000 -0.179000 -0.100000   0.116000  -0.015000
# 92  0.108000  0.093000 -0.052000 -0.034000  0.031000   0.116000  -0.022000
#
#     L0_S0_F14  L0_S0_F16  L0_S0_F18  ...  L3_S50_F4245  L3_S50_F4247  \
# Id                                   ...
# 6    0.002095   0.000978   0.001397  ...     -0.000004      0.000023
# 9    0.128000  -0.026000  -0.046000  ...     -0.000004      0.000023
# 82  -0.072000  -0.092000  -0.174000  ...     -0.000004      0.000023
# 91  -0.152000   0.316000  -0.056000  ...     -0.000004      0.000023
# 92  -0.072000  -0.067000   0.109000  ...     -0.000004      0.000023
#
# ...

# %%
# extract the columns which does not have 0.0 
train_date = train_date.loc[:, (train_date != 0).any(axis=0)]

# %%
train_date.head()
# Out:
#     L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# Id
# 6  -0.002354 -0.002962 -0.000949 -0.001195  0.000837   0.004747   0.000382
# 9  -0.036000 -0.064000  0.294000  0.330000  0.074000   0.161000   0.022000
# 82 -0.016000  0.041000 -0.179000 -0.197000 -0.273000  -0.430000  -0.007000
# 91  0.036000  0.101000 -0.161000 -0.179000 -0.100000   0.116000  -0.015000
# 92  0.108000  0.093000 -0.052000 -0.034000  0.031000   0.116000  -0.022000
#
#     L0_S0_F14  L0_S0_F16  L0_S0_F18  ...  L3_S50_F4243  L3_S50_F4245  \
# Id                                   ...
# 6    0.002095   0.000978   0.001397  ...     -0.004174     -0.000004
# 9    0.128000  -0.026000  -0.046000  ...     -0.004174     -0.000004
# 82  -0.072000  -0.092000  -0.174000  ...     -0.004174     -0.000004
# 91  -0.152000   0.316000  -0.056000  ...     -0.004174     -0.000004
# 92  -0.072000  -0.067000   0.109000  ...     -0.004174     -0.000004
#
# ...

# %%
corr_matrix = train_date.corr().abs()
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
# Find index of feature columns with correlation greater than 0.50
to_drop = [column for column in upper.columns if any(upper[column] > 0.70)]
print("train_date Drop: ", to_drop)
# Out:
# train_date Drop:  ['L0_S0_F2', 'L0_S0_F6', 'L0_S0_F12', 'L0_S0_F14', 'L0_S0_F22', 'L0_S2_F40', 'L0_S2_F56', 'L0_S3_F88', 'L0_S3_F92', 'L0_S6_F122', 'L0_S7_F138', 'L0_S8_F149', 'L0_S9_F180', 'L0_S9_F200', 'L0_S10_F244', 'L0_S10_F264', 'L0_S11_F302', 'L0_S11_F318', 'L0_S11_F322', 'L0_S12_F332', 'L0_S12_F336', 'L0_S12_F340', 'L0_S12_F342', 'L0_S12_F344', 'L0_S12_F352', 'L0_S14_F366', 'L0_S14_F382', 'L0_S15_F412', 'L0_S20_F466', 'L0_S21_F497', 'L0_S21_F517', 'L0_S21_F522', 'L0_S21_F527', 'L0_S21_F532', 'L0_S21_F537', 'L0_S22_F556', 'L0_S22_F571', 'L0_S22_F596', 'L0_S22_F601', 'L0_S22_F606', 'L0_S22_F611', 'L0_S23_F627', 'L0_S23_F639', 'L0_S23_F659', 'L0_S23_F663', 'L0_S23_F667', 'L1_S24_F746', 'L1_S24_F756', 'L1_S24_F766', 'L1_S24_F775', 'L1_S24_F780', 'L1_S24_F785', 'L1_S24_F790', 'L1_S24_F795', 'L1_S24_F806', 'L1_S24_F808', 'L1_S24_F812', 'L1_S24_F839', 'L1_S24_F844', 'L1_S24_F862', 'L1_S24_F867', 'L1_S24_F877', 'L1_S24_F882', 'L1_S24_F892', 'L1_S24_F902', 'L1_S24_F935', 'L1_S24_F953',
# ...

# %%
train_date = train_date.drop(to_drop,axis=1)

# %%
train_date.shape
# Out:
# (10000, 631)

# %%
corr_matrix = round(train_date.corr(),8)

# %%
corr_matrix.head()
# Out:
#            L0_S0_F0  L0_S0_F4  L0_S0_F8  L0_S0_F10  L0_S0_F16  L0_S0_F18  \
# L0_S0_F0   1.000000 -0.022981 -0.048890  -0.023143   0.177381   0.233007
# L0_S0_F4  -0.022981  1.000000 -0.017294   0.052416   0.077522   0.049397
# L0_S0_F8  -0.048890 -0.017294  1.000000   0.514977   0.074978   0.118151
# L0_S0_F10 -0.023143  0.052416  0.514977   1.000000   0.235744   0.284375
# L0_S0_F16  0.177381  0.077522  0.074978   0.235744   1.000000   0.615932
#
#            L0_S0_F20  L0_S1_F24  L0_S1_F28  L0_S2_F32  ...  L3_S49_F4236  \
# L0_S0_F0    0.136567   0.145250  -0.014177   0.080403  ...      0.005708
# L0_S0_F4   -0.015942   0.160622   0.106401  -0.021996  ...     -0.002269
# L0_S0_F8   -0.072627   0.006441  -0.051857  -0.017736  ...     -0.007586
# L0_S0_F10  -0.038062   0.312001  -0.029208   0.019481  ...     -0.001079
# L0_S0_F16   0.010652   0.046264   0.059571   0.018079  ...      0.025985
#
#            L3_S50_F4241  L3_S50_F4243  L3_S50_F4245  L3_S50_F4247  \
# ...

# %%
cov_matrix_invs = np.linalg.inv(np.cov(train_date,rowvar=0))

# %%
len(cov_matrix_invs)
# Out:
# 631

# %%
cov_matrix_invs= np.asmatrix(cov_matrix_invs)

# %%
cov_matrix_invs
# Out:
# matrix([[ 3.57686236e+02,  5.12044548e+00, -2.16913485e+01, ...,
#           2.78632484e+03, -1.25178800e+01,  1.91680158e+00],
#         [ 5.12044548e+00,  5.04450647e+01, -1.48479725e+00, ...,
#          -1.98129612e+03,  3.99811561e+00,  1.28500031e+00],
#         [-2.16913485e+01, -1.48479725e+00,  3.72315319e+02, ...,
#           1.41958164e+04, -4.70127426e+01,  7.56498651e-01],
#         ...,
#         [ 2.78632484e+03, -1.98129612e+03,  1.41958164e+04, ...,
#           5.24817169e+09,  3.26054798e+05,  2.92782131e+03],
#         [-1.25178800e+01,  3.99811561e+00, -4.70127426e+01, ...,
#           3.26054798e+05,  1.21136983e+05,  2.35711088e+01],
#         [ 1.91680158e+00,  1.28500031e+00,  7.56498651e-01, ...,
#           2.92782131e+03,  2.35711088e+01,  2.05005587e+02]])

# %%
# mean of the all columns value
mean_of_matrix2 = np.mean(train_date, axis=0)

# %%
# simple subtraction 
509.050000 -  877.852694
# Out:
# -368.80269400000003

# %%
mean_of_matrix2.head()
# Out:
# L0_S0_F0    -0.002354
# L0_S0_F4    -0.000949
# L0_S0_F8     0.000837
# L0_S0_F10    0.004747
# L0_S0_F16    0.000978
# dtype: float64

# %%
# Row's all value will be subtracted with mean of all columns value 
#(X-µ)
x_sub_mean_all = np.subtract(train_date, mean_of_matrix2)

# %%
x_sub_mean_all.head()
# Out:
#         L0_S0_F0      L0_S0_F4      L0_S0_F8     L0_S0_F10     L0_S0_F16  \
# Id
# 6   1.131907e-16 -6.667843e-17  2.179246e-17  2.983724e-16 -6.591949e-17
# 9  -3.364599e-02  2.949490e-01  7.316262e-02  1.562525e-01 -2.697829e-02
# 82 -1.364599e-02 -1.780510e-01 -2.738374e-01 -4.347475e-01 -9.297829e-02
# 91  3.835401e-02 -1.600510e-01 -1.008374e-01  1.112525e-01  3.150217e-01
# 92  1.103540e-01 -5.105099e-02  3.016262e-02  1.112525e-01 -6.797829e-02
#
#        L0_S0_F18     L0_S0_F20     L0_S1_F24     L0_S1_F28     L0_S2_F32  ...  \
# Id                                                                        ...
# 6  -1.249001e-16  1.144917e-16 -1.366095e-16  8.651933e-17  1.511378e-16  ...
# 9  -4.739673e-02 -2.571401e-01  1.444211e-01 -6.439339e-03 -1.222147e-02  ...
# 82 -1.753967e-01 -2.011401e-01 -1.475789e-01  6.156066e-02  8.777853e-02  ...
# 91 -5.739673e-02  1.385995e-02  3.421098e-03  1.456066e-02 -1.222147e-02  ...
# ...

# %%
#x_sub_mean_all.L0_S0_D1[428]

# %%
# taking all index number in a array from train_date datafram  
index = train_date.index.values

# %%
index
# Out:
# array([     6,      9,     82, ..., 242163, 242177, 242189], dtype=int64)

# %%
x_sub_mean_all = pd.DataFrame(x_sub_mean_all,index=train_date.index.values)

# %%
x_sub_mean_all
# Out:
#             L0_S0_F0      L0_S0_F4      L0_S0_F8     L0_S0_F10     L0_S0_F16  \
# 6       1.131907e-16 -6.667843e-17  2.179246e-17  2.983724e-16 -6.591949e-17
# 9      -3.364599e-02  2.949490e-01  7.316262e-02  1.562525e-01 -2.697829e-02
# 82     -1.364599e-02 -1.780510e-01 -2.738374e-01 -4.347475e-01 -9.297829e-02
# 91      3.835401e-02 -1.600510e-01 -1.008374e-01  1.112525e-01  3.150217e-01
# 92      1.103540e-01 -5.105099e-02  3.016262e-02  1.112525e-01 -6.797829e-02
# 93     -2.664599e-02 -1.405099e-02  3.016262e-02  1.112525e-01  7.002171e-02
# 123    -2.064599e-02 -1.960510e-01 -5.683738e-02  6.525254e-02 -2.197829e-02
# 166     1.131907e-16 -6.667843e-17  2.179246e-17  2.983724e-16 -6.591949e-17
# 191     1.131907e-16 -6.667843e-17  2.179246e-17  2.983724e-16 -6.591949e-17
# 226    -6.459948e-04 -2.140510e-01  1.171626e-01  2.025254e-02  9.021705e-03
# 258     1.131907e-16 -6.667843e-17  2.179246e-17  2.983724e-16 -6.591949e-17
# ...

# %%
def Chebyshev_inequality(row_value, cov_matrix_invs):
    
    #(X-µ) transpose
    row_value_transpose = np.transpose(np.asmatrix(row_value))
    #print ("trns", row_value_transpose)
    x_mlp_cov = row_value* cov_matrix_invs
    #print ("x_mlp_cov", x_mlp_cov)
    
    x_mlp_cov_mlp_x_tsp = np.sqrt(x_mlp_cov * row_value_transpose)
    print (x_mlp_cov_mlp_x_tsp)
    if (x_mlp_cov_mlp_x_tsp > 79.435508432942):
        return False
    else: 
        return True

# %%
#Chebyshev_inequality(x_sub_mean_all.loc[1228].values,cov_matrix_invs)

# %%
index_rslt = []
index_val = []
index_value_false = []
for i in index:
    rslt = Chebyshev_inequality(x_sub_mean_all.loc[i].values, cov_matrix_invs)
    index_rslt.append(rslt)
    if (rslt == True):
        index_val.append(i)
    else:
        index_value_false.append(i)
# Out:
# [[51.13792504]]
# [[50.05895293]]
# [[50.46076357]]
# [[50.30173416]]
# [[51.05074034]]
# [[50.1611953]]
# [[51.6609328]]
# [[52.70065849]]
# [[52.43157889]]
# [[50.37267819]]
# [[69.41489744]]
# [[51.43905541]]
# [[77.6257332]]
# [[50.13987942]]
# [[51.88498845]]
# [[52.90649019]]
# [[53.89461804]]
# [[53.77259442]]
# [[50.05212412]]
# [[50.60741199]]
# [[52.43229032]]
# [[56.80837981]]
# [[50.33683315]]
# [[50.50067803]]
# [[50.16442177]]
# [[51.06749508]]
# [[66.1925028]]
# [[51.0145785]]
# [[50.14046423]]
# [[63.36953539]]
# [[50.37426025]]
# [[50.85503153]]
# [[51.74058023]]
# [[55.02064742]]
# [[50.12032794]]
# [[52.34926981]]
# [[51.10719192]]
# [[51.30480044]]
# [[55.50324054]]
# [[50.30798196]]
# [[57.57451882]]
# [[53.60441471]]
# [[51.82285655]]
# [[50.23660818]]
# [[74.32651699]]
# [[51.70321865]]
# [[51.80476812]]
# [[50.75965817]]
# [[52.35328306]]
# [[57.42627745]]
# [[61.12115842]]
# [[53.51367348]]
# [[64.00444247]]
# [[51.74945469]]
# [[53.25233226]]
# ...

# %%
len(index_rslt)
# Out:
# 10000

# %%
index_rslt
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
true_v = len(index_val)
true_v
# Out:
# 9724

# %%
false_v = len(index_value_false)
false_v
# Out:
# 276

# %%
import matplotlib.pyplot as plt
fig1 = plt.figure()
ax1 = fig1.add_axes([0,0,1,1])
langs = ['True (Accepted rows)', ' False (Rejected rows)']
categorise = [true_v,false_v]

plt.title('Chebyshev’s inequality results')
plt.xlabel('Number of categorise')
plt.ylabel('Number of rows')

ax1.bar(langs,categorise)
plt.savefig('D:/input output csv_png/PNG/Chebyshev.png')
plt.show()

# %%
x_sub_mean_all.iloc[0].values
# Out:
# array([-1.28571429, -1.28571429,  0.85714286, -1.28571429,  0.14285714])

# %%
matrix2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e95820d6e01c> in <module>
# ----> 1 matrix2
#
# NameError: name 'matrix2' is not defined

# %%
co_v_M = np.cov(matrix2,rowvar=0)

# %%
co_v_M_I = np.linalg.inv(co_v_M)

# %%
co_v_M_I
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-98188bc5f219> in <module>
# ----> 1 co_v_M_I
#
# NameError: name 'co_v_M_I' is not defined

# %%
mean_of_matrix2 = np.mean(matrix2, axis=0)

# %%
mean_of_matrix2
# Out:
# matrix([[4.28571429, 3.28571429, 3.14285714, 3.28571429, 3.85714286]])

# %%
#(X-µ)
x_sub_mean = np.subtract(matrix2[5], mean_of_matrix2)

# %%
x_sub_mean
# Out:
# matrix([[-2.28571429, -0.28571429,  0.85714286,  1.71428571,  3.14285714]])

# %%
#(X-µ) transpose
x_mean_transpose = numpy.transpose(x_sub_mean)
x_mean_transpose
# Out:
# matrix([[-2.28571429],
#         [-0.28571429],
#         [ 0.85714286],
#         [ 1.71428571],
#         [ 3.14285714]])

# %%
co_v_M_I
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-98188bc5f219> in <module>
# ----> 1 co_v_M_I
#
# NameError: name 'co_v_M_I' is not defined

# %%
Final111 = x_sub_mean* co_v_M_I
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-abdaa7e0d988> in <module>
# ----> 1 Final111 = x_sub_mean* co_v_M_I
#
# NameError: name 'co_v_M_I' is not defined

# %%
Final111
# Out:
# matrix([[-0.24237647, -0.91451843, -0.3870999 ,  0.70512957,  0.9471325 ]])

# %%
final12 = Final111 * x_mean_transpose;

# %%
final12
# Out:
# matrix([[4.66899012]])

# %%
np.sqrt(final12)
# Out:
# matrix([[2.16078461]])

# %%
#define T value 
t = 631/0.1

# %%
t
# Out:
# 6310.0

# %%
np.sqrt(t)
# Out:
# 79.435508432942

# %%
empoyees = [(11, 5, 4, nan, 7) ,
          (12, nan, 1, nan , 7) ,
          (13, 1, 6, 0, 8) ,
          (14, 4, 1,nan , 9)
           ]
 
# Create a DataFrame object
empDfObj = pd.DataFrame(empoyees, columns=['ID' , 'Name', 'Age', 'City', 'Salary'])
 
# Set 'ID' as the index of the dataframe
empDfObj.set_index('ID', inplace=True)
empDfObj
# Out:
#     Name  Age  City  Salary
# ID
# 11   5.0    4   NaN       7
# 12   NaN    1   NaN       7
# 13   1.0    6   0.0       8
# 14   4.0    1   NaN       9

# %%
empDfObj=empDfObj.fillna(empDfObj.mean())

# %%
empDfObj
# Out:
#         Name  Age  City  Salary
# ID
# 11  5.000000    4   0.0       7
# 12  3.333333    1   0.0       7
# 13  1.000000    6   0.0       8
# 14  4.000000    1   0.0       9

# %%
empDfObj.loc[:, (empDfObj != 0).any(axis=0)]
# Out:
#         Name  Age  Salary
# ID
# 11  5.000000    4       7
# 12  3.333333    1       7
# 13  1.000000    6       8
# 14  4.000000    1       9

# %%
empDfObj.mean()
# Out:
# Name      3.333333
# Age       3.000000
# City      0.000000
# Salary    7.750000
# dtype: float64

# %%
empDfObj.loc[[11],:]
# Out:
#     Name  Age  City  Salary
# ID
# 11     5    4     6       7

# %%
7999-7882
# Out:
# 117

# %%
276/100
# Out:
# 2.76
